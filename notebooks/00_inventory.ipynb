# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()

if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

SRC_ROOT = PROJECT_ROOT / "src"

if str(SRC_ROOT) not in sys.path:
    sys.path.insert(0, str(SRC_ROOT))

from wizard.inventory import (
    build_inventory,
    duplicate_groups,
    inventory_summary,
    save_inventory,
)

# %%
CORPUS_DIR = Path(r"D:/baseia_v3/corpus/")
OUTPUT_DIR = PROJECT_ROOT / "data" / "inventory"

RECURSIVE = True
WORKERS = 10

# %%
inventory, errors = build_inventory(
    CORPUS_DIR,
    recursive=RECURSIVE,
    workers=WORKERS,
)
# Out:
# Processados: 100/3429
# Processados: 200/3429
# Processados: 300/3429
# Multiple definitions in dictionary at byte 0x2f383f for key /Title
# Processados: 400/3429
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 30 0 (offset 0)
# Ignoring wrong pointing object 57 0 (offset 0)
# Ignoring wrong pointing object 59 0 (offset 0)
# Ignoring wrong pointing object 61 0 (offset 0)
# PdfReadError("Invalid Elementary Object starting with b'P' @4898: b'0 0 obj<</Universal PDF(The process that creates this PDF constitutes a trade se'")
# Ignoring wrong pointing object 2576 0 (offset 0)
# Ignoring wrong pointing object 2577 0 (offset 0)
# Ignoring wrong pointing object 2858 0 (offset 0)
# Ignoring wrong pointing object 2859 0 (offset 0)
# Ignoring wrong pointing object 2860 0 (offset 0)
# Ignoring wrong pointing object 2861 0 (offset 0)
# Ignoring wrong pointing object 2 65536 (offset 0)
# Ignoring wrong pointing object 2862 0 (offset 0)
# Ignoring wrong pointing object 14 65536 (offset 0)
# Ignoring wrong pointing object 2863 0 (offset 0)
# Ignoring wrong pointing object 43 65536 (offset 0)
# Ignoring wrong pointing object 2864 0 (offset 0)
# Ignoring wrong pointing object 59 65536 (offset 0)
# Ignoring wrong pointing object 2865 0 (offset 0)
# Ignoring wrong pointing object 79 65536 (offset 0)
# Processados: 500/3429
# Ignoring wrong pointing object 2866 0 (offset 0)
# Ignoring wrong pointing object 97 65536 (offset 0)
# Ignoring wrong pointing object 2867 0 (offset 0)
# Ignoring wrong pointing object 113 65536 (offset 0)
# Ignoring wrong pointing object 2868 0 (offset 0)
# Ignoring wrong pointing object 137 65536 (offset 0)
# Ignoring wrong pointing object 2869 0 (offset 0)
# Ignoring wrong pointing object 161 65536 (offset 0)
# Ignoring wrong pointing object 2870 0 (offset 0)
# Ignoring wrong pointing object 2871 0 (offset 0)
# Ignoring wrong pointing object 2872 0 (offset 0)
# Ignoring wrong pointing object 2873 0 (offset 0)
# Ignoring wrong pointing object 2874 0 (offset 0)
# Ignoring wrong pointing object 2875 0 (offset 0)
# Ignoring wrong pointing object 3286 0 (offset 0)
# Ignoring wrong pointing object 3287 0 (offset 0)
# PdfReadError("Invalid Elementary Object starting with b'P' @6293: b'0 0 obj<</Universal PDF(The process that creates this PDF constitutes a trade se'")
# Ignoring wrong pointing object 3373 0 (offset 0)
# Ignoring wrong pointing object 3388 0 (offset 0)
# Processados: 600/3429
# Processados: 700/3429
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 18 0 (offset 0)
# Ignoring wrong pointing object 20 0 (offset 0)
# Processados: 800/3429
# Ignoring wrong pointing object 34 0 (offset 0)
# Ignoring wrong pointing object 44 0 (offset 0)
# Processados: 900/3429
# Processados: 1000/3429
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 21 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 23 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 25 0 (offset 0)
# Ignoring wrong pointing object 22 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 16 0 (offset 0)
# Ignoring wrong pointing object 29 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 25 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 24 0 (offset 0)
# Ignoring wrong pointing object 31 0 (offset 0)
# Ignoring wrong pointing object 12 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 30 0 (offset 0)
# Ignoring wrong pointing object 20 0 (offset 0)
# Ignoring wrong pointing object 28 0 (offset 0)
# Ignoring wrong pointing object 33 0 (offset 0)
# Ignoring wrong pointing object 30 0 (offset 0)
# Ignoring wrong pointing object 21 0 (offset 0)
# Ignoring wrong pointing object 53 0 (offset 0)
# Ignoring wrong pointing object 22 0 (offset 0)
# Ignoring wrong pointing object 35 0 (offset 0)
# Ignoring wrong pointing object 37 0 (offset 0)
# Ignoring wrong pointing object 57 0 (offset 0)
# Ignoring wrong pointing object 30 0 (offset 0)
# Ignoring wrong pointing object 61 0 (offset 0)
# Ignoring wrong pointing object 25 0 (offset 0)
# Ignoring wrong pointing object 49 0 (offset 0)
# Ignoring wrong pointing object 39 0 (offset 0)
# Processados: 1100/3429
# Ignoring wrong pointing object 59 0 (offset 0)
# Ignoring wrong pointing object 32 0 (offset 0)
# Ignoring wrong pointing object 64 0 (offset 0)
# Ignoring wrong pointing object 27 0 (offset 0)
# Ignoring wrong pointing object 51 0 (offset 0)
# Ignoring wrong pointing object 41 0 (offset 0)
# Ignoring wrong pointing object 61 0 (offset 0)
# Ignoring wrong pointing object 44 0 (offset 0)
# Ignoring wrong pointing object 71 0 (offset 0)
# Ignoring wrong pointing object 29 0 (offset 0)
# Ignoring wrong pointing object 53 0 (offset 0)
# Ignoring wrong pointing object 43 0 (offset 0)
# Ignoring wrong pointing object 50 0 (offset 0)
# Ignoring wrong pointing object 73 0 (offset 0)
# Ignoring wrong pointing object 31 0 (offset 0)
# Ignoring wrong pointing object 55 0 (offset 0)
# Ignoring wrong pointing object 45 0 (offset 0)
# Ignoring wrong pointing object 52 0 (offset 0)
# Ignoring wrong pointing object 79 0 (offset 0)
# Ignoring wrong pointing object 33 0 (offset 0)
# Ignoring wrong pointing object 57 0 (offset 0)
# Ignoring wrong pointing object 53 0 (offset 0)
# Ignoring wrong pointing object 60 0 (offset 0)
# Ignoring wrong pointing object 35 0 (offset 0)
# Ignoring wrong pointing object 63 0 (offset 0)
# Ignoring wrong pointing object 55 0 (offset 0)
# Ignoring wrong pointing object 64 0 (offset 0)
# Ignoring wrong pointing object 37 0 (offset 0)
# Ignoring wrong pointing object 65 0 (offset 0)
# Ignoring wrong pointing object 57 0 (offset 0)
# Ignoring wrong pointing object 75 0 (offset 0)
# Ignoring wrong pointing object 39 0 (offset 0)
# Ignoring wrong pointing object 68 0 (offset 0)
# Ignoring wrong pointing object 61 0 (offset 0)
# Ignoring wrong pointing object 41 0 (offset 0)
# Ignoring wrong pointing object 70 0 (offset 0)
# Ignoring wrong pointing object 63 0 (offset 0)
# Ignoring wrong pointing object 43 0 (offset 0)
# Ignoring wrong pointing object 72 0 (offset 0)
# Ignoring wrong pointing object 65 0 (offset 0)
# Ignoring wrong pointing object 47 0 (offset 0)
# Ignoring wrong pointing object 85 0 (offset 0)
# Ignoring wrong pointing object 71 0 (offset 0)
# Ignoring wrong pointing object 49 0 (offset 0)
# Ignoring wrong pointing object 87 0 (offset 0)
# Ignoring wrong pointing object 73 0 (offset 0)
# Ignoring wrong pointing object 51 0 (offset 0)
# Ignoring wrong pointing object 89 0 (offset 0)
# Ignoring wrong pointing object 75 0 (offset 0)
# Ignoring wrong pointing object 59 0 (offset 0)
# Ignoring wrong pointing object 93 0 (offset 0)
# Ignoring wrong pointing object 77 0 (offset 0)
# Ignoring wrong pointing object 61 0 (offset 0)
# Ignoring wrong pointing object 99 0 (offset 0)
# Ignoring wrong pointing object 1480 0 (offset 0)
# Ignoring wrong pointing object 63 0 (offset 0)
# Ignoring wrong pointing object 101 0 (offset 0)
# Ignoring wrong pointing object 65 0 (offset 0)
# Ignoring wrong pointing object 103 0 (offset 0)
# Ignoring wrong pointing object 67 0 (offset 0)
# Ignoring wrong pointing object 69 0 (offset 0)
# Ignoring wrong pointing object 71 0 (offset 0)
# Ignoring wrong pointing object 73 0 (offset 0)
# Ignoring wrong pointing object 75 0 (offset 0)
# Ignoring wrong pointing object 87 0 (offset 0)
# Ignoring wrong pointing object 89 0 (offset 0)
# Ignoring wrong pointing object 101 0 (offset 0)
# Ignoring wrong pointing object 103 0 (offset 0)
# Processados: 1200/3429
# Processados: 1300/3429
# Processados: 1400/3429
# Processados: 1500/3429
# Processados: 1600/3429
# Processados: 1700/3429
# EOF marker not found
# Processados: 1800/3429
# Processados: 1900/3429
# Processados: 2000/3429
# Processados: 2100/3429
# Processados: 2200/3429
# Processados: 2300/3429
# Processados: 2400/3429
# Processados: 2500/3429
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 14 0 (offset 0)
# Ignoring wrong pointing object 26 0 (offset 0)
# Ignoring wrong pointing object 34 0 (offset 0)
# Ignoring wrong pointing object 46 0 (offset 0)
# Ignoring wrong pointing object 48 0 (offset 0)
# Ignoring wrong pointing object 50 0 (offset 0)
# Ignoring wrong pointing object 52 0 (offset 0)
# Ignoring wrong pointing object 60 0 (offset 0)
# Ignoring wrong pointing object 62 0 (offset 0)
# Ignoring wrong pointing object 64 0 (offset 0)
# Ignoring wrong pointing object 66 0 (offset 0)
# Ignoring wrong pointing object 68 0 (offset 0)
# Ignoring wrong pointing object 70 0 (offset 0)
# Ignoring wrong pointing object 72 0 (offset 0)
# Ignoring wrong pointing object 74 0 (offset 0)
# Ignoring wrong pointing object 76 0 (offset 0)
# Ignoring wrong pointing object 78 0 (offset 0)
# Ignoring wrong pointing object 81 0 (offset 0)
# Ignoring wrong pointing object 83 0 (offset 0)
# Ignoring wrong pointing object 91 0 (offset 0)
# Ignoring wrong pointing object 93 0 (offset 0)
# Ignoring wrong pointing object 95 0 (offset 0)
# Ignoring wrong pointing object 97 0 (offset 0)
# Ignoring wrong pointing object 99 0 (offset 0)
# Ignoring wrong pointing object 101 0 (offset 0)
# Ignoring wrong pointing object 103 0 (offset 0)
# Ignoring wrong pointing object 105 0 (offset 0)
# Ignoring wrong pointing object 107 0 (offset 0)
# Ignoring wrong pointing object 109 0 (offset 0)
# Ignoring wrong pointing object 111 0 (offset 0)
# Ignoring wrong pointing object 113 0 (offset 0)
# Ignoring wrong pointing object 115 0 (offset 0)
# Ignoring wrong pointing object 117 0 (offset 0)
# Ignoring wrong pointing object 119 0 (offset 0)
# Ignoring wrong pointing object 121 0 (offset 0)
# Ignoring wrong pointing object 123 0 (offset 0)
# Ignoring wrong pointing object 125 0 (offset 0)
# EOF marker not found
# Processados: 2600/3429
# Processados: 2700/3429
# Processados: 2800/3429
# Processados: 2900/3429
# Processados: 3000/3429
# Processados: 3100/3429
# Multiple definitions in dictionary at byte 0xd7998 for key /MediaBox
# Multiple definitions in dictionary at byte 0xd7b9c for key /MediaBox
# Multiple definitions in dictionary at byte 0xd7d35 for key /MediaBox
# Multiple definitions in dictionary at byte 0xd7ecf for key /MediaBox
# Multiple definitions in dictionary at byte 0xd8023 for key /MediaBox
# Multiple definitions in dictionary at byte 0xd815f for key /MediaBox
# Ignoring wrong pointing object 8 0 (offset 0)
# Multiple definitions in dictionary at byte 0xd829b for key /MediaBox
# Ignoring wrong pointing object 10 0 (offset 0)
# Multiple definitions in dictionary at byte 0xd8407 for key /MediaBox
# Ignoring wrong pointing object 15 0 (offset 0)
# Multiple definitions in dictionary at byte 0xd8553 for key /MediaBox
# Ignoring wrong pointing object 17 0 (offset 0)
# Multiple definitions in dictionary at byte 0xd869f for key /MediaBox
# Ignoring wrong pointing object 29 0 (offset 0)
# Multiple definitions in dictionary at byte 0xd87eb for key /MediaBox
# Ignoring wrong pointing object 31 0 (offset 0)
# Multiple definitions in dictionary at byte 0xd896f for key /MediaBox
# Ignoring wrong pointing object 101 0 (offset 0)
# Multiple definitions in dictionary at byte 0xd8ad3 for key /MediaBox
# Multiple definitions in dictionary at byte 0xd8c1f for key /MediaBox
# Multiple definitions in dictionary at byte 0xd8d83 for key /MediaBox
# Multiple definitions in dictionary at byte 0xd8eef for key /MediaBox
# Multiple definitions in dictionary at byte 0xd9073 for key /MediaBox
# Multiple definitions in dictionary at byte 0xd9217 for key /MediaBox
# Multiple definitions in dictionary at byte 0xd937b for key /MediaBox
# Multiple definitions in dictionary at byte 0xd94e8 for key /MediaBox
# Multiple definitions in dictionary at byte 0xd9644 for key /MediaBox
# Multiple definitions in dictionary at byte 0xd9790 for key /MediaBox
# Multiple definitions in dictionary at byte 0xd992c for key /MediaBox
# Multiple definitions in dictionary at byte 0xd9af8 for key /MediaBox
# Processados: 3200/3429
# PdfReadError("Invalid Elementary Object starting with b'P' @1073004: b'9 0 obj<</Universal PDF(The process that creates this PDF constitutes a trade se'")
# Ignoring wrong pointing object 4128 0 (offset 0)
# Ignoring wrong pointing object 4129 0 (offset 0)
# Ignoring wrong pointing object 4346 0 (offset 0)
# Ignoring wrong pointing object 4347 0 (offset 0)
# Ignoring wrong pointing object 4348 0 (offset 0)
# Ignoring wrong pointing object 4349 0 (offset 0)
# Ignoring wrong pointing object 4350 0 (offset 0)
# Ignoring wrong pointing object 4351 0 (offset 0)
# Ignoring wrong pointing object 4352 0 (offset 0)
# Ignoring wrong pointing object 4353 0 (offset 0)
# Ignoring wrong pointing object 4354 0 (offset 0)
# Ignoring wrong pointing object 4355 0 (offset 0)
# Ignoring wrong pointing object 4356 0 (offset 0)
# Ignoring wrong pointing object 4357 0 (offset 0)
# Ignoring wrong pointing object 4358 0 (offset 0)
# Ignoring wrong pointing object 4359 0 (offset 0)
# Ignoring wrong pointing object 4360 0 (offset 0)
# Ignoring wrong pointing object 4361 0 (offset 0)
# Ignoring wrong pointing object 4362 0 (offset 0)
# Ignoring wrong pointing object 4363 0 (offset 0)
# Ignoring wrong pointing object 4364 0 (offset 0)
# Ignoring wrong pointing object 4365 0 (offset 0)
# Ignoring wrong pointing object 4366 0 (offset 0)
# Ignoring wrong pointing object 4367 0 (offset 0)
# Ignoring wrong pointing object 4368 0 (offset 0)
# Ignoring wrong pointing object 4369 0 (offset 0)
# Ignoring wrong pointing object 4370 0 (offset 0)
# Ignoring wrong pointing object 4371 0 (offset 0)
# Ignoring wrong pointing object 4372 0 (offset 0)
# Ignoring wrong pointing object 4373 0 (offset 0)
# Ignoring wrong pointing object 4374 0 (offset 0)
# Ignoring wrong pointing object 4375 0 (offset 0)
# Ignoring wrong pointing object 4376 0 (offset 0)
# Ignoring wrong pointing object 4377 0 (offset 0)
# Ignoring wrong pointing object 4378 0 (offset 0)
# Ignoring wrong pointing object 4379 0 (offset 0)
# Ignoring wrong pointing object 4380 0 (offset 0)
# Ignoring wrong pointing object 4381 0 (offset 0)
# Ignoring wrong pointing object 4913 0 (offset 0)
# Ignoring wrong pointing object 4914 0 (offset 0)
# Ignoring wrong pointing object 5031 0 (offset 0)
# Ignoring wrong pointing object 5045 0 (offset 0)
# Processados: 3300/3429
# incorrect startxref pointer(1)
# parsing for Object Streams
# Processados: 3400/3429
# PdfReadError("Invalid Elementary Object starting with b'P' @6189: b'3 0 obj<</Universal PDF(The process that creates this PDF constitutes a trade se'")
# Processados: 3429/3429

# %%
inventory.head()
# Out:
#         document_id                                             sha256  \
# 0  415c1ac896f59486  415c1ac896f594865c2f1f427d7b4f504e5a402b32f063...
# 1  ff4ca23d0f16d57f  ff4ca23d0f16d57f82f5b2446f2ae3dafc72166d260a07...
# 2  ce2c31a603353dbd  ce2c31a603353dbdac0bde49e43b3149ada42e15aba926...
# 3  39f7076074f617aa  39f7076074f617aa8d5c6d6c281f19ba49104c58ef2904...
# 4  974bbe22ff347665  974bbe22ff347665410c629724e75ee83af3108a9fdef4...
#
#                                                 path  \
# 0  D:\baseia_v3\corpus\00 - Preço de Liquidação d...
# 1                 D:\baseia_v3\corpus\010+n7+BJD.pdf
# 2                  D:\baseia_v3\corpus\0605582v2.pdf
# 3  D:\baseia_v3\corpus\1-s2.0-S0169207014001083-m...
# 4  D:\baseia_v3\corpus\1-s2.0-S2666546824000880-m...
#
#                                        relative_path  \
# 0  00 - Preço de Liquidação das Diferenças_2023.3...
# 1                                     010+n7+BJD.pdf
# 2                                      0605582v2.pdf
# 3                  1-s2.0-S0169207014001083-main.pdf
# 4                  1-s2.0-S2666546824000880-main.pdf
#
#                                             filename  \
# 0  00 - Preço de Liquidação das Diferenças_2023.3...
# 1                                     010+n7+BJD.pdf
# 2                                      0605582v2.pdf
# 3                  1-s2.0-S0169207014001083-main.pdf
# 4                  1-s2.0-S2666546824000880-main.pdf
#
#                                                 stem extension  size_bytes  \
# 0  00 - Preço de Liquidação das Diferenças_2023.3...      .pdf     1890470
# 1                                         010+n7+BJD      .pdf      575632
# 2                                          0605582v2      .pdf      335288
# 3                      1-s2.0-S0169207014001083-main      .pdf     3041424
# 4                      1-s2.0-S2666546824000880-main      .pdf     4962478
#
#    size_mb                        created_at  ... page_count  encrypted  \
# 0   1.8029  2026-07-27T23:59:49.566359+00:00  ...       25.0      False
# 1   0.5490  2026-07-28T00:00:16.726151+00:00  ...       19.0      False
# 2   0.3198  2026-07-28T00:00:16.798797+00:00  ...       24.0      False
# 3   2.9005  2026-07-28T00:00:16.799798+00:00  ...       52.0      False
# 4   4.7326  2026-07-28T00:00:16.728151+00:00  ...       14.0      False
#
#   pdf_version                                              title  \
# 0         1.7  Microsoft Word - 00 - Preço de Liquidação das ...
# 1         1.3                                    ISSN: 2525-8761
# 2         1.4     Bayesian analysis for reversible Markov chains
# 3         1.7  Electricity price forecasting: A review of the...
# 4         1.7  Probabilistic simulation of electricity price ...
#
#                                author  \
# 0                           rcarneiro
# 1                     Priscila Viégas
# 2  Persi Diaconis, Silke W. W. Rolles
# 3                         Rafał Weron
# 4                       Viktor Walter
#
#                                              subject  \
# 0                                                NaN
# 1                                                NaN
# 2  The Annals of Statistics, 2006, Vol.34, No.3, ...
# 3  International Journal of Forecasting, 30 (2014...
# 4  Energy and AI, 18 (2024) 100422. doi:10.1016/j...
#
#                        creator                                     producer  \
# 0                          NaN                      Microsoft: Print To PDF
# 1         Microsoft® Word 2019                         Microsoft® Word 2019
# 2  LaTeX with hyperref package  dvips + GPL Ghostscript GIT PRERELEASE 9.22
# 3                     Elsevier                                pdfTeX-1.40.3
# 4                     Elsevier            Acrobat Distiller 8.1.0 (Windows)
#
#   status error
# 0     ok   NaN
# 1     ok   NaN
# 2     ok   NaN
# 3     ok   NaN
# 4     ok   NaN
#
# [5 rows x 21 columns]

# %%
inventory_summary(inventory)
# Out:
# documents_total       3429.0000
# documents_ok          3427.0000
# documents_error          2.0000
# encrypted                9.0000
# size_total_gb            6.0663
# size_median_mb           0.9397
# pages_total         114742.0000
# pages_median             9.0000
# duplicate_files         93.0000
# duplicate_groups        46.0000
# dtype: float64

# %%
inventory[
    [
        "filename",
        "size_mb",
        "page_count",
        "encrypted",
        "status",
    ]
].describe(include="all")
# Out:
#                                                  filename      size_mb  \
# count                                                3429  3429.000000
# unique                                               3429          NaN
# top     00 - Preço de Liquidação das Diferenças_2023.3...          NaN
# freq                                                    1          NaN
# mean                                                  NaN     1.811584
# std                                                   NaN     4.337658
# min                                                   NaN     0.002400
# 25%                                                   NaN     0.532500
# 50%                                                   NaN     0.939700
# 75%                                                   NaN     1.618700
# max                                                   NaN    80.219600
#
#          page_count encrypted status
# count   3427.000000      3427   3429
# unique          NaN         2      2
# top             NaN     False     ok
# freq            NaN      3418   3427
# mean      33.481762       NaN    NaN
# std      108.059015       NaN    NaN
# min        1.000000       NaN    NaN
# 25%        8.000000       NaN    NaN
# 50%        9.000000       NaN    NaN
# 75%       11.000000       NaN    NaN
# max     1411.000000       NaN    NaN

# %%
inventory["status"].value_counts(dropna=False)
# Out:
# status
# ok       3427
# error       2
# Name: count, dtype: int64

# %%
inventory["page_count"].describe(percentiles=[0.25, 0.50, 0.75, 0.90, 0.95, 0.99])
# Out:
# count    3427.000000
# mean       33.481762
# std       108.059015
# min         1.000000
# 25%         8.000000
# 50%         9.000000
# 75%        11.000000
# 90%        22.000000
# 95%       168.700000
# 99%       545.000000
# max      1411.000000
# Name: page_count, dtype: float64

# %%
inventory["size_mb"].describe(percentiles=[0.25, 0.50, 0.75, 0.90, 0.95, 0.99])
# Out:
# count    3429.000000
# mean        1.811584
# std         4.337658
# min         0.002400
# 25%         0.532500
# 50%         0.939700
# 75%         1.618700
# 90%         3.021540
# 95%         5.081560
# 99%        17.230700
# max        80.219600
# Name: size_mb, dtype: float64

# %%
duplicates = duplicate_groups(inventory)
duplicates
# Out:
#          document_id                                             sha256  \
# 0   0033d9791d44daff  0033d9791d44daff6c0fb83a1cadd1f38f545ac968f601...
# 1   0033d9791d44daff  0033d9791d44daff6c0fb83a1cadd1f38f545ac968f601...
# 2   03bd2b697923f28f  03bd2b697923f28f787fde919e7fd4aa14c38ff7827ffe...
# 3   03bd2b697923f28f  03bd2b697923f28f787fde919e7fd4aa14c38ff7827ffe...
# 4   05de4fa5028344bb  05de4fa5028344bbbf233bf77b8efc3fc4eb6d50ad28da...
# ..               ...                                                ...
# 88  f08623831fdd2bfb  f08623831fdd2bfbeb2a7726eb3cb39814281df13a0bfe...
# 89  f3f327ad78f6b56f  f3f327ad78f6b56f2c7dad9407ed1b1cac2d3f3ff2fd80...
# 90  f3f327ad78f6b56f  f3f327ad78f6b56f2c7dad9407ed1b1cac2d3f3ff2fd80...
# 91  f4a0e4b6ee6cab09  f4a0e4b6ee6cab091aad87c9d10eab82b93c8d415fccef...
# 92  f4a0e4b6ee6cab09  f4a0e4b6ee6cab091aad87c9d10eab82b93c8d415fccef...
#
#                                                  path  \
# 0   D:\baseia_v3\corpus\Chain-optimazation-pscc-20...
# 1   D:\baseia_v3\corpus\ChainOfOptModelsForSetting...
# 2   D:\baseia_v3\corpus\A INFLUÊNCIA DAS CARACTERÍ...
# 3                    D:\baseia_v3\corpus\GAE_0382.pdf
# 4                    D:\baseia_v3\corpus\GDS_1190.pdf
# ..                                                ...
# 88  D:\baseia_v3\corpus\Investidores estrangeiros ...
# 89                   D:\baseia_v3\corpus\GDI_0137.pdf
# 90  D:\baseia_v3\corpus\SISTEMA DE MONITORAMENTO P...
# 91                   D:\baseia_v3\corpus\GDI_0959.pdf
# 92  D:\baseia_v3\corpus\IMPACTOS DOS RECURSOS ENER...
#
#                                         relative_path  \
# 0                    Chain-optimazation-pscc-2002.pdf
# 1   ChainOfOptModelsForSettingTheEnergyDispatchAnd...
# 2   A INFLUÊNCIA DAS CARACTERÍSTICAS DO CAMPO ORGA...
# 3                                        GAE_0382.pdf
# 4                                        GDS_1190.pdf
# ..                                                ...
# 88  Investidores estrangeiros no mercado de energi...
# 89                                       GDI_0137.pdf
# 90  SISTEMA DE MONITORAMENTO PARA REDES DE DISTRIB...
# 91                                       GDI_0959.pdf
# 92  IMPACTOS DOS RECURSOS ENERGÉTICOS DISTRIBUÍDOS...
#
#                                              filename  \
# 0                    Chain-optimazation-pscc-2002.pdf
# 1   ChainOfOptModelsForSettingTheEnergyDispatchAnd...
# 2   A INFLUÊNCIA DAS CARACTERÍSTICAS DO CAMPO ORGA...
# 3                                        GAE_0382.pdf
# 4                                        GDS_1190.pdf
# ..                                                ...
# 88  Investidores estrangeiros no mercado de energi...
# 89                                       GDI_0137.pdf
# 90  SISTEMA DE MONITORAMENTO PARA REDES DE DISTRIB...
# 91                                       GDI_0959.pdf
# 92  IMPACTOS DOS RECURSOS ENERGÉTICOS DISTRIBUÍDOS...
#
#                                                  stem extension  size_bytes  \
# 0                        Chain-optimazation-pscc-2002      .pdf      167420
# 1   ChainOfOptModelsForSettingTheEnergyDispatchAnd...      .pdf      167420
# 2   A INFLUÊNCIA DAS CARACTERÍSTICAS DO CAMPO ORGA...      .pdf      820838
# 3                                            GAE_0382      .pdf      820838
# 4                                            GDS_1190      .pdf     1018369
# ..                                                ...       ...         ...
# 88  Investidores estrangeiros no mercado de energi...      .pdf      424123
# 89                                           GDI_0137      .pdf     1334177
# 90  SISTEMA DE MONITORAMENTO PARA REDES DE DISTRIB...      .pdf     1334177
# 91                                           GDI_0959      .pdf      598551
# 92  IMPACTOS DOS RECURSOS ENERGÉTICOS DISTRIBUÍDOS...      .pdf      598551
#
#     size_mb                        created_at  ... page_count  encrypted  \
# 0    0.1597  2026-07-28T00:00:16.754539+00:00  ...        7.0       True
# 1    0.1597  2026-07-28T00:00:16.809798+00:00  ...        7.0       True
# 2    0.7828  2026-07-28T00:01:24.684688+00:00  ...       10.0      False
# 3    0.7828  2026-07-28T00:02:50.128885+00:00  ...       10.0      False
# 4    0.9712  2026-07-28T00:02:50.103248+00:00  ...        9.0      False
# ..      ...                               ...  ...        ...        ...
# 88   0.4045  2026-07-28T00:01:24.649617+00:00  ...        9.0      False
# 89   1.2724  2026-07-28T00:02:49.292950+00:00  ...       10.0      False
# 90   1.2724  2026-07-28T00:01:24.665682+00:00  ...       10.0      False
# 91   0.5708  2026-07-28T00:02:49.318955+00:00  ...        9.0      False
# 92   0.5708  2026-07-28T00:01:24.668688+00:00  ...        9.0      False
#
#    pdf_version                           title             author subject  \
# 0          1.4                       SAPPE.PDF             elvira     NaN
# 1          1.4                       SAPPE.PDF             elvira     NaN
# 2          1.7   Microsoft Word - GAE-382.docx  Gabriel Magalhaes     NaN
# 3          1.7   Microsoft Word - GAE-382.docx  Gabriel Magalhaes     NaN
# 4          1.7  Microsoft Word - GDS-1190.docx  Gabriel Magalhaes     NaN
# ..         ...                             ...                ...     ...
# 88         1.7                 [GEC]-3930.docx       Eduarda Melo     NaN
# 89         1.7   Microsoft Word - GDI-137.docx             magluz     NaN
# 90         1.7   Microsoft Word - GDI-137.docx             magluz     NaN
# 91         1.7   Microsoft Word - GDI-959.docx             magluz     NaN
# 92         1.7   Microsoft Word - GDI-959.docx             magluz     NaN
#
#            creator                           producer status error
# 0   Microsoft Word  Acrobat PDFWriter 4.0 for Windows     ok   NaN
# 1   Microsoft Word  Acrobat PDFWriter 4.0 for Windows     ok   NaN
# 2              NaN            Microsoft: Print To PDF     ok   NaN
# 3              NaN            Microsoft: Print To PDF     ok   NaN
# 4              NaN            Microsoft: Print To PDF     ok   NaN
# ..             ...                                ...    ...   ...
# 88             NaN            Microsoft: Print To PDF     ok   NaN
# 89             NaN            Microsoft: Print To PDF     ok   NaN
# 90             NaN            Microsoft: Print To PDF     ok   NaN
# 91             NaN            Microsoft: Print To PDF     ok   NaN
# 92             NaN            Microsoft: Print To PDF     ok   NaN
#
# [93 rows x 21 columns]

# %%
errors
# Out:
#                              path relative_path    filename  \
# 0  D:\baseia_v3\corpus\GIA 32.pdf    GIA 32.pdf  GIA 32.pdf
# 1  D:\baseia_v3\corpus\GPT 10.pdf    GPT 10.pdf  GPT 10.pdf
#
#                                            error
# 0  PdfStreamError: Stream has ended unexpectedly
# 1  PdfStreamError: Stream has ended unexpectedly

# %%
largest_documents = inventory.sort_values(
    "size_bytes",
    ascending=False,
).head(30)

largest_documents[["filename", "size_mb", "page_count", "relative_path"]]
# Out:
#                                                filename  size_mb  page_count  \
# 576   Feature Engineering and Selection A Practical ...  80.2196       314.0
# 518   Data-Driven Science and Engineering Machine Le...  72.7336       495.0
# 229        2018_Book_DataScienceAndPredictiveAnalyt.pdf  65.4326       851.0
# 517   Data Smart Using Data Science to Transform Inf...  64.5063       434.0
# 513   Data Science for Business and Decision Making ...  61.7239      1209.0
# 3337  The Definitive Guide to DAX-Business intellige...  58.7986       589.0
# 3338  The Definitive Guide to DAX-Business intellige...  57.7293       589.0
# 3167                    Introduction to Data Mining.pdf  55.5958       792.0
# 3219  Manual de Analise de Dados by Luiz Paulo Fáver...  48.3669      1219.0
# 3202  Machine Learning Engineering by Andriy Burkov.pdf  48.1591       296.0
# 3140  Hands-On Machine Learning with Scikit-Learn an...  45.3066       564.0
# 3260  Pesquisa operacional Para Cursos De Engenharia...  43.7158       545.0
# 435   AI and Machine Learning for Coders A Programme...  34.5462       390.0
# 3141  Hands-On Machine Learning with Scikit-Learn, K...  31.9050       510.0
# 3168  Introduction to Machine Learning with Python A...  31.6179       392.0
# 253        2019_Book_ABeginnersGuideToPython3Progra.pdf  29.0539       441.0
# 526   Deep Learning A Practitioners Approach by J. P...  27.1899       532.0
# 540   Doing Data Science Straight Talk from the Fron...  27.0731       405.0
# 3200  Machine Learning A Probabilistic Perspective b...  25.6945      1098.0
# 3259  Pesquisa operacional Para Cursos De Administra...  24.5857       360.0
# 177                       2004_Book_AllOfStatistics.pdf  23.2860       446.0
# 3207  Machine Learning for Hackers by Drew Conway, J...  23.0829       322.0
# 254        2019_Book_AdvancedGuideToPython3Programm.pdf  22.9095       494.0
# 3163                  Intelig_ncia_Artif(z-lib.org).pdf  22.7512      1324.0
# 475   Book_Power BI from Rookie to Rock Star_Book03_...  22.6778       594.0
# 3240                     Neural_Networks_for_Patter.pdf  22.4394       498.0
# 3269  Predictive Analytics The Power to Predict Who ...  21.1513       361.0
# 3172  Introduction_to_Operations_Reserarch(BookZZ.or...  19.7567      1411.0
# 3263  Practical Machine Learning with Python A Probl...  19.3918       545.0
# 528   Deep Learning by Ian Goodfellow, Yoshua Bengio...  18.3907       801.0
#
#                                           relative_path
# 576   Feature Engineering and Selection A Practical ...
# 518   Data-Driven Science and Engineering Machine Le...
# 229        2018_Book_DataScienceAndPredictiveAnalyt.pdf
# 517   Data Smart Using Data Science to Transform Inf...
# 513   Data Science for Business and Decision Making ...
# 3337  The Definitive Guide to DAX-Business intellige...
# 3338  The Definitive Guide to DAX-Business intellige...
# 3167                    Introduction to Data Mining.pdf
# 3219  Manual de Analise de Dados by Luiz Paulo Fáver...
# 3202  Machine Learning Engineering by Andriy Burkov.pdf
# 3140  Hands-On Machine Learning with Scikit-Learn an...
# 3260  Pesquisa operacional Para Cursos De Engenharia...
# 435   AI and Machine Learning for Coders A Programme...
# 3141  Hands-On Machine Learning with Scikit-Learn, K...
# 3168  Introduction to Machine Learning with Python A...
# 253        2019_Book_ABeginnersGuideToPython3Progra.pdf
# 526   Deep Learning A Practitioners Approach by J. P...
# 540   Doing Data Science Straight Talk from the Fron...
# 3200  Machine Learning A Probabilistic Perspective b...
# 3259  Pesquisa operacional Para Cursos De Administra...
# 177                       2004_Book_AllOfStatistics.pdf
# 3207  Machine Learning for Hackers by Drew Conway, J...
# 254        2019_Book_AdvancedGuideToPython3Programm.pdf
# 3163                  Intelig_ncia_Artif(z-lib.org).pdf
# 475   Book_Power BI from Rookie to Rock Star_Book03_...
# 3240                     Neural_Networks_for_Patter.pdf
# 3269  Predictive Analytics The Power to Predict Who ...
# 3172  Introduction_to_Operations_Reserarch(BookZZ.or...
# 3263  Practical Machine Learning with Python A Probl...
# 528   Deep Learning by Ian Goodfellow, Yoshua Bengio...

# %%
longest_documents = inventory.sort_values(
    "page_count",
    ascending=False,
).head(30)

longest_documents[["filename", "page_count", "size_mb", "relative_path"]]
# Out:
#                                                filename  page_count  size_mb  \
# 3172  Introduction_to_Operations_Reserarch(BookZZ.or...      1411.0  19.7567
# 3163                  Intelig_ncia_Artif(z-lib.org).pdf      1324.0  22.7512
# 3219  Manual de Analise de Dados by Luiz Paulo Fáver...      1219.0  48.3669
# 513   Data Science for Business and Decision Making ...      1209.0  61.7239
# 461   Artificial Intelligence A Modern Approach, 3rd...      1151.0  17.2496
# 462   Artificial Intelligence A Modern Approach, 3rd...      1151.0  15.2759
# 3200  Machine Learning A Probabilistic Perspective b...      1098.0  25.6945
# 191        2016_Book_APrimerOnScientificProgramming.pdf       942.0   8.7175
# 190        2015_Book_StatisticalAnalysisAndDataDisp.pdf       909.0  18.3544
# 229        2018_Book_DataScienceAndPredictiveAnalyt.pdf       851.0  65.4326
# 3261  Practical Data Science A Guide to Building the...       821.0   7.5703
# 528   Deep Learning by Ian Goodfellow, Yoshua Bengio...       801.0  18.3907
# 3167                    Introduction to Data Mining.pdf       792.0  55.5958
# 180                    2013 Matrix Computations 4th.pdf       780.0  13.1387
# 3255                     Pattern_Recognition_and_Ma.pdf       761.0   4.5129
# 578                        Fluent_Python(z-lib.org).pdf       751.0  17.5275
# 188                            2015_Book_DataMining.pdf       746.0  16.4296
# 520   Data-Mining.-Concepts-and-Techniques-3rd-Editi...       740.0  12.0023
# 3361  Time Series Analysis Forecasting and Control b...       709.0  13.5009
# 3279  Python Machine Learning Machine Learning and D...       622.0  10.7927
# 3336        The Data Warehouse Toolkit, 3rd Edition.pdf       601.0   5.4796
# 413   92.Applied.Predictive.Modeling.Techniques.in.R...       599.0  14.9852
# 475   Book_Power BI from Rookie to Rock Star_Book03_...       594.0  22.6778
# 3338  The Definitive Guide to DAX-Business intellige...       589.0  57.7293
# 3337  The Definitive Guide to DAX-Business intellige...       589.0  58.7986
# 187        2015_Book_AppliedMultivariateStatistical.pdf       581.0  11.8320
# 3381                           better_deep_learning.pdf       575.0   9.4178
# 3386          deep_learning_time_series_forecasting.pdf       572.0   8.1419
# 509                      Data Analysis and Graphics.pdf       565.0   5.9791
# 3140  Hands-On Machine Learning with Scikit-Learn an...       564.0  45.3066
#
#                                           relative_path
# 3172  Introduction_to_Operations_Reserarch(BookZZ.or...
# 3163                  Intelig_ncia_Artif(z-lib.org).pdf
# 3219  Manual de Analise de Dados by Luiz Paulo Fáver...
# 513   Data Science for Business and Decision Making ...
# 461   Artificial Intelligence A Modern Approach, 3rd...
# 462   Artificial Intelligence A Modern Approach, 3rd...
# 3200  Machine Learning A Probabilistic Perspective b...
# 191        2016_Book_APrimerOnScientificProgramming.pdf
# 190        2015_Book_StatisticalAnalysisAndDataDisp.pdf
# 229        2018_Book_DataScienceAndPredictiveAnalyt.pdf
# 3261  Practical Data Science A Guide to Building the...
# 528   Deep Learning by Ian Goodfellow, Yoshua Bengio...
# 3167                    Introduction to Data Mining.pdf
# 180                    2013 Matrix Computations 4th.pdf
# 3255                     Pattern_Recognition_and_Ma.pdf
# 578                        Fluent_Python(z-lib.org).pdf
# 188                            2015_Book_DataMining.pdf
# 520   Data-Mining.-Concepts-and-Techniques-3rd-Editi...
# 3361  Time Series Analysis Forecasting and Control b...
# 3279  Python Machine Learning Machine Learning and D...
# 3336        The Data Warehouse Toolkit, 3rd Edition.pdf
# 413   92.Applied.Predictive.Modeling.Techniques.in.R...
# 475   Book_Power BI from Rookie to Rock Star_Book03_...
# 3338  The Definitive Guide to DAX-Business intellige...
# 3337  The Definitive Guide to DAX-Business intellige...
# 187        2015_Book_AppliedMultivariateStatistical.pdf
# 3381                           better_deep_learning.pdf
# 3386          deep_learning_time_series_forecasting.pdf
# 509                      Data Analysis and Graphics.pdf
# 3140  Hands-On Machine Learning with Scikit-Learn an...

# %%
saved_paths = save_inventory(
    inventory,
    errors,
    OUTPUT_DIR,
)

saved_paths
# Out:
# {'inventory_parquet': WindowsPath('D:/baseia_v3/data/inventory/inventory.parquet'),
#  'inventory_csv': WindowsPath('D:/baseia_v3/data/inventory/inventory.csv'),
#  'errors_csv': WindowsPath('D:/baseia_v3/data/inventory/inventory_errors.csv'),
#  'duplicates_csv': WindowsPath('D:/baseia_v3/data/inventory/inventory_duplicates.csv'),
#  'summary_json': WindowsPath('D:/baseia_v3/data/inventory/inventory_summary.json')}
